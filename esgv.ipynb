# %%
import esgvoc, cmipld, glob
from esgvoc.api import data_descriptors as dd
import json
import re
cmipld.map_current(cmipld.prefix())
# Out:
# Initializing LDR client...
# Current server mappings: {'cf:*': 'https://wcrp-cmip.github.io/CF/${rest}', 'vr:*': 'https://wcrp-cmip.github.io/Variable-Registry/${rest}', 'emd:*': 'https://wcrp-cmip.github.io/Essential-Model-Documentation/${rest}', 'cmip7:*': 'https://wcrp-cmip.github.io/CMIP7-CVs/${rest}', 'universal:*': 'https://wcrp-cmip.github.io/WCRP-universe/${rest}', 'cmip6plus:*': 'https://wcrp-cmip.github.io/CMIP6Plus_CVs/${rest}', 'https://cf.mipcvs.dev/*': 'https://wcrp-cmip.github.io/CF/${rest}', 'https://vr.mipcvs.dev/*': 'https://wcrp-cmip.github.io/Variable-Registry/${rest}', 'https://emd.mipcvs.dev/*': 'https://wcrp-cmip.github.io/Essential-Model-Documentation/${rest}', 'https://cmip7.mipcvs.dev/*': 'https://wcrp-cmip.github.io/CMIP7-CVs/${rest}', 'https://universal.mipcvs.dev/*': 'https://wcrp-cmip.github.io/WCRP-universe/${rest}', 'https://cmip6plus.mipcvs.dev/*': 'https://wcrp-cmip.github.io/CMIP6Plus_CVs/${rest}'}
# LDR client initialized.
# ...

# %%
folders = glob.glob('*/')
folders
# Out:
# ['arrangement/',
#  'calendar/',
#  'license/',
#  'frequency/',
#  'source_type/',
#  'activity/',
#  'vertical_coordinate/',
#  'truncation_method/',
#  'model_component_type/',
#  'product/',
#  'mip/',
#  'temporal_refinement/',
#  'units/',
#  'scientific_domain/',
#  'region/',
#  'resolution/',
#  'organisation/',
#  'grid_mapping/',
#  'model_calendar/',
#  'archive_id/',
#  'grid_type/',
#  'cell_variable_type/']

# %%
for f in folders:
    print(f)
    
    ctx = json.load(open(f'./{f}_context')).get('@context', {})
    esgname = ctx.get('@esgvoc')
    print(esgname)
    
    
    model = getattr(dd, esgname)
    
    
    print(model)
    
    
    
    files = glob.glob(f'{f}*.json')
    print(files)
    
    item = cmipld.get('emd:_graph.jsonld')
    
    
    
    break
# Out:
# 2026-01-28 13:43:37,676 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x108796410>: Failed to establish a new connection: [Errno 61] Connection refused')': /compact
# arrangement/
# Arrangement
# <class 'esgvoc.api.data_descriptors.EMD_models.arrangement.Arrangement'>
# ['arrangement/arakawa-b.json', 'arrangement/arakawa-c.json', 'arrangement/arakawa-d.json', 'arrangement/arakawa-e.json', 'arrangement/arakawa-a.json']
# 2026-01-28 13:43:39,690 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1087968c0>: Failed to establish a new connection: [Errno 61] Connection refused')': /compact
# ...

# %%
getattr(dd, 'Activity')
# Out:
# typing.Annotated[typing.Union[typing.Annotated[esgvoc.api.data_descriptors.activity.ActivityCMIP7, Tag(tag='ActivityCMIP7')], typing.Annotated[esgvoc.api.data_descriptors.activity.ActivityLegacy, Tag(tag='ActivityLegacy')]], Discriminator(discriminator=<function create_union.<locals>.property_discriminator at 0x117ae40d0>, custom_error_type=None, custom_error_message=None, custom_error_context=None)]

# %%
help(esgvoc)

# %%
glob.glob(f'{f}*.json')
# Out:
# ['arrangement/arakawa-b.json',
#  'arrangement/arakawa-c.json',
#  'arrangement/arakawa-d.json',
#  'arrangement/arakawa-e.json',
#  'arrangement/arakawa-a.json']

# %%
'esgvoc install'
